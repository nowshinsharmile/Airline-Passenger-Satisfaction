# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df = pd.read_csv("/Users/Susmi/Desktop/Python/Part_2/522275_959195_bundle_archive/train_plane.csv")
df=df.drop(['sl','id'],axis=1) #remove unnecessary data
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
def fillmissing_numeric(table, col_name):
    table[col_name] = table[col_name].astype('float64')
    table[col_name].fillna(table[col_name].mean(), inplace=True)
fillmissing_numeric(df, 'Arrival Delay in Minutes')   
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
print(df['Customer Type'].value_counts())
print(df['Class'].value_counts())
print(df['Type of Travel'].value_counts())
print(df['satisfaction'].value_counts())
print(df['Gender'].value_counts())
df.info()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
# ...

# %%
df[['Class','Age']].groupby('Class').mean()
# Out:
#                 Age
# Class
# Business  41.574328
# Eco       37.164253
# Eco Plus  38.654524

# %%
sns.boxplot(x='satisfaction', y='Flight Distance', data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Inflight wifi service', data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Departure/Arrival time convenient', data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Ease of Online booking', data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Food and drink',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Gate location',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Online boarding',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Seat comfort',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Inflight entertainment',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='On-board service',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Leg room service',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Baggage handling',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Checkin service',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Inflight service',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Cleanliness',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Departure Delay in Minutes',  data=df)
plt.show()

# %%
sns.boxplot(x='satisfaction', y='Arrival Delay in Minutes',  data=df)
plt.show()

# %% [markdown]
# Here we see that, other than Gate location, Departure and Arrival Delay and Time conveninent pretty much all numerical value somewhat varies with satisfaction, which can also be seen in the correlation matrix in the modeling file

# %%
sns.boxplot(x='satisfaction', y='Age', hue = 'Gender',data=df)
plt.show()

# %%
sns.violinplot(x='satisfaction', y ='Age', data = df, hue ='Gender', split = True)

# %%
sns.boxplot(x='Inflight wifi service',y = 'Online boarding',data=df)

# %% [markdown]
# People who gets better service of inflight wifi likely to apply for online boarding and gives better rating.

# %%
with sns.axes_style('white'):
    g = sns.catplot("Age", data=df, aspect=4.0, kind='count', hue='satisfaction', order=range(6, 85))
    g.set_ylabels('Age vs Passenger Satisfaction')

# %%
sns.kdeplot(df.loc[(df['Gender'] == 'Male'), 'Age'], shade = True, color = 'b', label = 'Male')
sns.kdeplot(df.loc[(df['Gender'] == 'Female'), 'Age'], shade = True, color = 'g', label = 'Female')
plt.title('Age Distribution by Gender')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Gender')

# %%
sns.distplot(df['Flight Distance'], bins = 15)
plt.title('Flight Distance Distribution')
# Out:
# Text(0.5, 1.0, 'Flight Distance Distribution')

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 16))

table1 = pd.crosstab(df['satisfaction'], df['Online boarding'])
sns.heatmap(table1, cmap='Oranges', ax = axarr[0][0])
table2 = pd.crosstab(df['satisfaction'], df['Inflight entertainment'])
sns.heatmap(table2, cmap='Blues', ax = axarr[0][1])
table3 = pd.crosstab(df['satisfaction'], df['On-board service'])
sns.heatmap(table3, cmap='pink', ax = axarr[1][0])
table4 = pd.crosstab(df['satisfaction'], df['Seat comfort'])
sns.heatmap(table4, cmap='bone', ax = axarr[1][1])

# %%
from scipy import stats
def chi_sq_test(DF, var1, var2):
    dataset_table = pd.crosstab(DF[var1], DF[var2])
    print('contingency table between {} and {} is:\n'.format(var1, var2))
    print(dataset_table)
    val = stats.chi2_contingency(dataset_table)
    Observed_Values = dataset_table.values 
    Expected_Values = val[-1]
    no_of_rows = dataset_table.shape[0]
    no_of_columns = dataset_table.shape[1]
    ddof = (no_of_rows-1)*(no_of_columns-1)
    print("\nDegree of Freedom:-",ddof)
    alpha = 0.05
    chi_square = sum([(o-e)**2./e for o,e in zip(Observed_Values, Expected_Values)])
    chi_square_statistic = chi_square[0]+chi_square[1]
    critical_value = stats.chi2.ppf(q=1-alpha,df=ddof)
    p_value = 1-stats.chi2.cdf(x=chi_square_statistic,df=ddof)
    
    if chi_square_statistic>=critical_value and p_value<=alpha:
        print("chi_square_statistic is {} and p-value is {}. So, there is a relationship between 2 categorical variables".format(chi_square_statistic, p_value))
    elif chi_square_statistic>=critical_value and p_value>alpha:
        print("chi_square_statistic is {} and p-value is {}. So, there is a weak relationship between 2 categorical variables, but not evident enough".format(chi_square_statistic, p_value))
    else:
        print("chi_square_statistic is {} and p-value is {}. So, these 2 variables are not related at all.".format(chi_square_statistic, p_value))

# %%
chi_sq_test(df, 'Gender', 'satisfaction')
# Out:
# contingency table between Gender and satisfaction is:
#
# satisfaction  neutral or dissatisfied  satisfied
# Gender
# Female                          30193      22534
# Male                            28686      22491
#
# Degree of Freedom:- 1
# chi_square_statistic is 15.493668870573623 and p-value is 8.278205965517316e-05. So, there is a relationship between 2 categorical variables

# %% [markdown]
# it means gender - wise, satisfaction varies

# %%
chi_sq_test(df, 'Type of Travel', 'satisfaction')
# Out:
# contingency table between Type of Travel and satisfaction is:
#
# satisfaction     neutral or dissatisfied  satisfied
# Type of Travel
# Business travel                    29909      41746
# Personal Travel                    28970       3279
#
# Degree of Freedom:- 1
# chi_square_statistic is 20947.192277056274 and p-value is 0.0. So, there is a relationship between 2 categorical variables

# %%
chi_sq_test(df, 'Customer Type', 'satisfaction')
# Out:
# contingency table between Customer Type and satisfaction is:
#
# satisfaction       neutral or dissatisfied  satisfied
# Customer Type
# Loyal Customer                       44390      40533
# disloyal Customer                    14489       4492
#
# Degree of Freedom:- 1
# chi_square_statistic is 3658.260694673255 and p-value is 0.0. So, there is a relationship between 2 categorical variables

# %%
chi_sq_test(df, 'Class', 'satisfaction')
# Out:
# contingency table between Class and satisfaction is:
#
# satisfaction  neutral or dissatisfied  satisfied
# Class
# Business                        15185      34480
# Eco                             38044       8701
# Eco Plus                         5650       1844
#
# Degree of Freedom:- 2
# chi_square_statistic is 26471.86294449228 and p-value is 0.0. So, there is a relationship between 2 categorical variables
